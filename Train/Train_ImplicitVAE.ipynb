# %%
# Initialize drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Move to Google Drive 
# %cd drive
# %cd 'My Drive'
# %cd 'MSc Stats Dissertation'
# Out:
# /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/MSc Stats Dissertation

# %%
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras as keras
import tensorflow.keras.layers  as layers
import pandas as pd
import math
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
BATCH_NORM = True
CONV_ACTIVATION = 'tanh'
CONV_DEPTH = 4
CONV_DIM_DEPTH = 32
CONV_DIM_WIDTH = 16
CONV_D_GF = 1.15875438383
CONV_W_GF = 1.1758149644
HIDDEN_DIM = 100

# %%
## Import Necessary Data for training
train_smiles_X = np.load('./vocab/train_selfies_X.npy',allow_pickle=True)
vocab =np.load('./vocab/selfies_vocab.npy',allow_pickle=True)
vocab_index = np.load('./vocab/selfies_vocab_index.npy',allow_pickle=True)
vocab = dict(vocab.ravel()[0])
vocab_index = dict(vocab_index.ravel()[0])

# %%
## Neccesary CONSTANTS
BATCH_SIZE = 256
VOCAB_SIZE = len(vocab)
EPOCHS = 40
LEARNING_RATE = 1e-4
Z_X_LEARNING_RATE= 1e-5
DROP_OUT= 0.2
EMBEDDING_DIM = 192  ## Embedding dim of the characters
PAD_LEN = 250 ## Maximum size of a SMILE (100 + BOS, EOS)
MAX_LEN = PAD_LEN -1
DROPOUT = 0.2
LATENT_DIM = 64
HIDDEN_DIM = 256

# %%
index = np.where(train_smiles_X == 1)
t = np.split(train_smiles_X,index[0].tolist())
t= t[1:]
t = tf.keras.preprocessing.sequence.pad_sequences(t,maxlen=PAD_LEN,padding='post')
NUM_BATCHES = math.floor(len(t)/BATCH_SIZE )

# %%
NUM_TRAIN_BATCH = math.floor(NUM_BATCHES*0.99)
NUM_TEST_BATCH = math.floor(NUM_BATCHES*(0.01))

# %%
test_X = t[NUM_TRAIN_BATCH*BATCH_SIZE:(NUM_TEST_BATCH+NUM_TRAIN_BATCH)*BATCH_SIZE]
train_X = t[:NUM_TRAIN_BATCH*BATCH_SIZE]

# %%
import math
def softmax_logits_loss_with_pad(labels,logits):
  weights = tf.cast(tf.not_equal(labels, 0), tf.float32)
  nonpad_seq = tf.math.count_nonzero(weights, dtype=tf.dtypes.float32, )
  loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits =logits)
  loss = tf.reduce_sum(loss *weights)
  return loss

# %%
## Cyclical Annealing ###
def frange_cycle_linear(n_iter, start=0.0, stop=1.0,  n_cycle=4, ratio=0.5):
  L = np.ones(n_iter) * stop
  period = n_iter/n_cycle
  step = (stop-start)/(period*ratio) # linear schedule
  for c in range(n_cycle):
    v, i = start, 0
    while v <= stop and (int(i+c*period) < n_iter):
      L[int(i+c*period)] = v
      v += step
      i += 1
  return L

# %%
def train_smile_vae(smile_ivae,train_X, test_X,model_type, betas, num_updates):
  clip = -1
  display_step = 100
  STEPS_PER_EPOCH = train_X.shape[0]//BATCH_SIZE
  TEST_STEPS = test_X.shape[0]//BATCH_SIZE

  ## Define optimizers
  optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
  optimizer_xz = tf.keras.optimizers.Adam(learning_rate=Z_X_LEARNING_RATE)
  optimizer_z = tf.keras.optimizers.Adam(learning_rate=Z_X_LEARNING_RATE)

  ## Cyclical Annealing index ##
  beta_ind = 0 

  for epoch in range(EPOCHS):
    indxs = np.arange(STEPS_PER_EPOCH)
    np.random.shuffle(indxs)
    for batch in range(STEPS_PER_EPOCH):
      ## Get relevant batch data
      X_batch = train_X[indxs[batch]*BATCH_SIZE: indxs[batch]*BATCH_SIZE + BATCH_SIZE]

      ## Update the auxillary network 
      for n in range(num_updates):  
        eps = tf.convert_to_tensor(np.random.normal(size=(X_batch.shape[0], LATENT_DIM)),dtype = tf.float32)
        with tf.GradientTape() as kl_xz_tape, tf.GradientTape() as kl_z_tape:

          ## Get encoding of training data
          enc, z_x = smile_ivae.encoder(X_batch[:,:-1],eps)
          kl_xz_vars = smile_ivae.nu_xz.trainable_variables 
          kl_z_vars = smile_ivae.nu_z.trainable_variables   
         
          ## Get logits of the model 
          kl_xz = smile_ivae.kl_xz_loss(z_x =z_x, enc = enc)
          kl_z  = smile_ivae.kl_z_loss(z_x = z_x)

        ## KL updates
        gradients = kl_xz_tape.gradient(kl_xz, kl_xz_vars)
        if clip != -1:
          gradients, _ = tf.clip_by_global_norm(gradients, clip) 
        optimizer_xz.apply_gradients(zip(gradients, kl_xz_vars))
        
        gradients = kl_z_tape.gradient(kl_z, kl_z_vars)
        if clip != -1:
          gradients, _ = tf.clip_by_global_norm(gradients, clip) 
        optimizer_z.apply_gradients(zip(gradients, kl_z_vars))

      with tf.GradientTape() as tape:
        ## end to end update for implict model 
        x_decoded, enc, z_x = smile_ivae(X_batch[:,:-1])
        vars = smile_ivae.decoder.trainable_variables
        vars.extend(smile_ivae.encoder.trainable_variables)
        loss_op = softmax_logits_loss_with_pad(labels=X_batch[:,1:],logits =x_decoded)

        ## Model update using auxillary network and softmax 
        if model_type == 'mle':
          loss_op = loss_op +( betas[beta_ind]*tf.reduce_sum(smile_ivae.nu_xz(z_x =z_x, enc = enc)))
        else:
          loss_op = loss_op  + (betas[beta_ind] *tf.reduce_sum(smile_ivae.nu_z(z_x = z_x)))
      gradients = tape.gradient(loss_op, vars)
      if clip != -1:
        gradients, _ = tf.clip_by_global_norm(gradients, clip) 
      optimizer.apply_gradients(zip(gradients, vars))

      ## Display training information
      if batch % display_step == 0 or batch == 1:
        ### Get logits for test data
        rand_int = np.random.randint(low=0,high = TEST_STEPS)
        test_batch = test_X[rand_int*BATCH_SIZE: rand_int*BATCH_SIZE + BATCH_SIZE ]
        x_decoded, enc, z_x = smile_ivae(test_batch[:,:-1])
        test_loss = softmax_logits_loss_with_pad(labels=test_batch[:,1:],logits =x_decoded)

        ## Get testing loss
        if model_type == 'mle':
          test_loss = test_loss +(betas[beta_ind]*tf.reduce_mean(smile_ivae.nu_xz(z_x =z_x, enc = enc)))
        else:
          test_loss = test_loss  + (betas[beta_ind] *tf.reduce_mean(smile_ivae.nu_z(z_x = z_x)))
        
        ## Get testing information for displaying accuracy ##
        pred_test = tf.nn.softmax(x_decoded,axis =-1)
        weights = tf.cast(tf.not_equal(test_batch[:,1:], 0), tf.float32)
        nonpad_seq = tf.math.count_nonzero(weights, dtype=tf.dtypes.float32, )
        correct_pred_test = tf.equal(tf.argmax(pred_test,-1),test_batch[:,1:])
        accuracy_test = tf.reduce_sum(tf.cast(correct_pred_test, tf.float32))/nonpad_seq

        ## Get regularizing loss for model 
        if model_type == 'mle':
          kl_loss = betas[beta_ind]*tf.reduce_sum(smile_ivae.nu_xz(z_x =z_x, enc = enc))
        else:
          kl_loss = betas[beta_ind] *tf.reduce_sum(smile_ivae.nu_z(z_x = z_x))
        ### Print out test accuracy on model  
        print("Step " + str(batch) + ", Training Loss = " + \
                "{:.3f}".format(loss_op) + ", Test Loss = " + \
                "{:.3f}".format(test_loss) + ", Test Accuracy = " + \
                "{:.3f}".format(accuracy_test) +", Implict KL value = " + \
                "{:.3f}".format(kl_loss))
      beta_ind+=1
      ## Save every so often
      if  (batch) % 3000 == 0:
        smile_ivae.save_weights('selfies_ivae_weights')

# %%
betas = frange_cycle_linear(train_X.shape[0]//BATCH_SIZE *EPOCHS)
smile_ivae = SMILE_IMPLICIT_VAE(vocab_size =VOCAB_SIZE,embedding_dim =EMBEDDING_DIM, 
              max_len =MAX_LEN, latent_dim=LATENT_DIM, hidden_dim= HIDDEN_DIM,
              recurrent_dropout =0.2,dropout_rate=0.2,epsilon_std = 1.0)

# %%
## Train with 3 updates of auxillary network for every end to 
## end update
train_smile_vae(smile_ivae,train_X,test_X,'mle_li',betas,3)
# Out:
# Step 0, Training Loss = 62735.016, Test Loss = 61558.016, Test Accuracy = 0.216, Implict KL value = -0.000
# Step 1, Training Loss = 66397.398, Test Loss = 60413.602, Test Accuracy = 0.242, Implict KL value = -0.000
# Step 100, Training Loss = 30763.246, Test Loss = 29791.525, Test Accuracy = 0.270, Implict KL value = 58.649
# Step 200, Training Loss = 27964.934, Test Loss = 28035.053, Test Accuracy = 0.253, Implict KL value = 166.675
# Step 300, Training Loss = 29332.871, Test Loss = 28312.623, Test Accuracy = 0.301, Implict KL value = 222.529
# Step 400, Training Loss = 31472.949, Test Loss = 28512.705, Test Accuracy = 0.296, Implict KL value = 120.018
# Step 500, Training Loss = 29511.568, Test Loss = 28056.635, Test Accuracy = 0.304, Implict KL value = 67.250
# Step 600, Training Loss = 29225.125, Test Loss = 26896.844, Test Accuracy = 0.325, Implict KL value = 44.876
# Step 700, Training Loss = 28374.314, Test Loss = 26805.777, Test Accuracy = 0.336, Implict KL value = 51.246
# Step 800, Training Loss = 25530.152, Test Loss = 25919.188, Test Accuracy = 0.348, Implict KL value = 101.543
# Step 900, Training Loss = 28574.391, Test Loss = 26217.328, Test Accuracy = 0.359, Implict KL value = 129.933
# Step 1000, Training Loss = 24772.426, Test Loss = 25136.094, Test Accuracy = 0.379, Implict KL value = 129.526
# Step 1100, Training Loss = 27244.004, Test Loss = 24414.725, Test Accuracy = 0.388, Implict KL value = 125.281
# Step 1200, Training Loss = 25597.074, Test Loss = 25151.943, Test Accuracy = 0.384, Implict KL value = 137.851
# Step 1300, Training Loss = 25689.078, Test Loss = 24016.195, Test Accuracy = 0.395, Implict KL value = 142.773
# Step 1400, Training Loss = 28216.512, Test Loss = 23626.127, Test Accuracy = 0.401, Implict KL value = 148.950
# Step 1500, Training Loss = 26781.412, Test Loss = 21571.725, Test Accuracy = 0.419, Implict KL value = 163.571
# Step 1600, Training Loss = 23560.637, Test Loss = 23170.719, Test Accuracy = 0.411, Implict KL value = 154.450
# Step 1700, Training Loss = 23655.219, Test Loss = 22624.559, Test Accuracy = 0.423, Implict KL value = 164.473
# Step 1800, Training Loss = 25863.410, Test Loss = 22380.562, Test Accuracy = 0.426, Implict KL value = 182.237
# Step 1900, Training Loss = 23106.783, Test Loss = 22023.896, Test Accuracy = 0.431, Implict KL value = 200.621
# Step 2000, Training Loss = 24782.125, Test Loss = 21645.945, Test Accuracy = 0.431, Implict KL value = 198.979
# Step 2100, Training Loss = 24706.527, Test Loss = 21986.551, Test Accuracy = 0.429, Implict KL value = 198.875
# Step 2200, Training Loss = 25241.010, Test Loss = 21194.461, Test Accuracy = 0.437, Implict KL value = 208.982
# Step 2300, Training Loss = 25303.613, Test Loss = 21084.783, Test Accuracy = 0.442, Implict KL value = 206.494
# Step 2400, Training Loss = 26086.812, Test Loss = 20693.891, Test Accuracy = 0.448, Implict KL value = 214.484
# Step 2500, Training Loss = 20261.355, Test Loss = 21308.861, Test Accuracy = 0.438, Implict KL value = 172.297
# Step 2600, Training Loss = 21332.533, Test Loss = 21563.527, Test Accuracy = 0.446, Implict KL value = 126.001
# Step 2700, Training Loss = 24011.738, Test Loss = 20957.143, Test Accuracy = 0.444, Implict KL value = 98.447
# Step 2800, Training Loss = 22615.107, Test Loss = 20796.432, Test Accuracy = 0.443, Implict KL value = 106.333
# Step 2900, Training Loss = 20809.734, Test Loss = 20982.635, Test Accuracy = 0.457, Implict KL value = 73.613
# Step 3000, Training Loss = 24055.311, Test Loss = 21281.389, Test Accuracy = 0.448, Implict KL value = 88.380
# Step 3100, Training Loss = 23825.654, Test Loss = 21150.283, Test Accuracy = 0.450, Implict KL value = 101.317
# Step 3200, Training Loss = 22881.660, Test Loss = 20899.207, Test Accuracy = 0.448, Implict KL value = 174.901
# Step 3300, Training Loss = 24627.598, Test Loss = 19570.076, Test Accuracy = 0.470, Implict KL value = 175.537
# Step 3400, Training Loss = 20371.803, Test Loss = 19974.002, Test Accuracy = 0.469, Implict KL value = 182.601
# Step 3500, Training Loss = 20794.062, Test Loss = 19152.697, Test Accuracy = 0.482, Implict KL value = 160.153
# Step 3600, Training Loss = 22705.674, Test Loss = 17971.355, Test Accuracy = 0.485, Implict KL value = 143.214
# Step 3700, Training Loss = 21707.199, Test Loss = 18396.736, Test Accuracy = 0.489, Implict KL value = 174.617
# Step 3800, Training Loss = 23672.352, Test Loss = 17720.623, Test Accuracy = 0.507, Implict KL value = 193.044
# Step 100, Training Loss = 17498.809, Test Loss = 14657.384, Test Accuracy = 0.617, Implict KL value = 117.902
# Step 200, Training Loss = 16951.508, Test Loss = 14330.193, Test Accuracy = 0.625, Implict KL value = 122.516
# Step 300, Training Loss = 16522.145, Test Loss = 13410.940, Test Accuracy = 0.642, Implict KL value = 150.836
# Step 400, Training Loss = 15939.262, Test Loss = 14380.572, Test Accuracy = 0.631, Implict KL value = 154.411
# Step 500, Training Loss = 13772.027, Test Loss = 13641.558, Test Accuracy = 0.637, Implict KL value = 158.630
# Step 600, Training Loss = 16767.850, Test Loss = 12911.067, Test Accuracy = 0.657, Implict KL value = 152.505
# Step 700, Training Loss = 15613.952, Test Loss = 13291.640, Test Accuracy = 0.655, Implict KL value = 154.332
# Step 800, Training Loss = 15007.227, Test Loss = 12703.219, Test Accuracy = 0.671, Implict KL value = 161.407
# Step 900, Training Loss = 15183.291, Test Loss = 12608.578, Test Accuracy = 0.664, Implict KL value = 166.269
# Step 1000, Training Loss = 14463.479, Test Loss = 11956.940, Test Accuracy = 0.671, Implict KL value = 161.222
# Step 1100, Training Loss = 13936.324, Test Loss = 12218.858, Test Accuracy = 0.688, Implict KL value = 174.667
# Step 1200, Training Loss = 19123.943, Test Loss = 12484.146, Test Accuracy = 0.676, Implict KL value = 193.217
# Step 1300, Training Loss = 13946.314, Test Loss = 13198.281, Test Accuracy = 0.664, Implict KL value = 190.432
# Step 1400, Training Loss = 12499.327, Test Loss = 12454.638, Test Accuracy = 0.683, Implict KL value = 197.925
# Step 1500, Training Loss = 13729.692, Test Loss = 12569.813, Test Accuracy = 0.676, Implict KL value = 213.832
# Step 1600, Training Loss = 14321.877, Test Loss = 10990.910, Test Accuracy = 0.700, Implict KL value = 216.341
# Step 1700, Training Loss = 13485.828, Test Loss = 11950.209, Test Accuracy = 0.692, Implict KL value = 226.493
# Step 1800, Training Loss = 13331.684, Test Loss = 11489.928, Test Accuracy = 0.694, Implict KL value = 239.443
# Step 1900, Training Loss = 13198.576, Test Loss = 11582.863, Test Accuracy = 0.695, Implict KL value = 219.412
# Step 2000, Training Loss = 12365.895, Test Loss = 11790.910, Test Accuracy = 0.700, Implict KL value = 249.515
# Step 2100, Training Loss = 14277.796, Test Loss = 12150.894, Test Accuracy = 0.689, Implict KL value = 241.138
# Step 2200, Training Loss = 13861.160, Test Loss = 11594.447, Test Accuracy = 0.689, Implict KL value = 249.428
# Step 2300, Training Loss = 14704.859, Test Loss = 10180.473, Test Accuracy = 0.724, Implict KL value = 258.455
# Step 2400, Training Loss = 14228.145, Test Loss = 11246.813, Test Accuracy = 0.703, Implict KL value = 248.635
# Step 2500, Training Loss = 11362.226, Test Loss = 11548.218, Test Accuracy = 0.703, Implict KL value = 264.165
# Step 2600, Training Loss = 13099.523, Test Loss = 10921.978, Test Accuracy = 0.719, Implict KL value = 267.254
# Step 2700, Training Loss = 13769.612, Test Loss = 10747.911, Test Accuracy = 0.723, Implict KL value = 266.196
# Step 2800, Training Loss = 15268.691, Test Loss = 10035.523, Test Accuracy = 0.734, Implict KL value = 246.501
# Step 5600, Training Loss = 11680.538, Test Loss = 8582.553, Test Accuracy = 0.768, Implict KL value = 361.695
# Step 5700, Training Loss = 9084.484, Test Loss = 8763.230, Test Accuracy = 0.767, Implict KL value = 305.721
# Step 5800, Training Loss = 9545.863, Test Loss = 8477.738, Test Accuracy = 0.783, Implict KL value = 307.010
# Step 5900, Training Loss = 11337.111, Test Loss = 8139.116, Test Accuracy = 0.767, Implict KL value = 254.773
# Step 6000, Training Loss = 11564.053, Test Loss = 10128.979, Test Accuracy = 0.733, Implict KL value = 262.951
# Step 6100, Training Loss = 11018.616, Test Loss = 8391.854, Test Accuracy = 0.772, Implict KL value = 291.804
# Step 6200, Training Loss = 11639.895, Test Loss = 8733.448, Test Accuracy = 0.767, Implict KL value = 57.770
# Step 6300, Training Loss = 8724.824, Test Loss = 8379.517, Test Accuracy = 0.782, Implict KL value = 344.903
# Step 0, Training Loss = 10922.339, Test Loss = 7780.987, Test Accuracy = 0.789, Implict KL value = 236.774
# Step 1, Training Loss = 9127.542, Test Loss = 8343.021, Test Accuracy = 0.780, Implict KL value = 222.265
# Step 100, Training Loss = 9462.064, Test Loss = 8196.925, Test Accuracy = 0.783, Implict KL value = 204.223
# Step 200, Training Loss = 9789.285, Test Loss = 8345.396, Test Accuracy = 0.781, Implict KL value = 380.276
# Step 300, Training Loss = 10589.884, Test Loss = 8547.958, Test Accuracy = 0.771, Implict KL value = 177.427
# Step 400, Training Loss = 10801.828, Test Loss = 8221.924, Test Accuracy = 0.780, Implict KL value = 275.607
# Step 500, Training Loss = 8768.557, Test Loss = 7793.993, Test Accuracy = 0.792, Implict KL value = 245.569
# Step 600, Training Loss = 10108.992, Test Loss = 8304.611, Test Accuracy = 0.780, Implict KL value = 454.118
# Step 700, Training Loss = 10934.564, Test Loss = 7941.538, Test Accuracy = 0.786, Implict KL value = 164.388
# Step 800, Training Loss = 11749.391, Test Loss = 8609.511, Test Accuracy = 0.776, Implict KL value = 471.960
# Step 900, Training Loss = 13196.100, Test Loss = 8112.263, Test Accuracy = 0.789, Implict KL value = 505.195
# Step 1000, Training Loss = 10927.989, Test Loss = 7941.576, Test Accuracy = 0.790, Implict KL value = 455.146
# Step 1100, Training Loss = 11199.210, Test Loss = 7901.178, Test Accuracy = 0.782, Implict KL value = 501.886
# Step 1200, Training Loss = 8777.219, Test Loss = 8005.117, Test Accuracy = 0.790, Implict KL value = 414.421
# Step 1300, Training Loss = 9973.953, Test Loss = 7746.318, Test Accuracy = 0.797, Implict KL value = 542.855
# Step 1400, Training Loss = 7633.497, Test Loss = 8081.404, Test Accuracy = 0.787, Implict KL value = 137.378
# Step 1500, Training Loss = 11632.183, Test Loss = 8324.523, Test Accuracy = 0.782, Implict KL value = 609.344
# Step 1600, Training Loss = 11658.280, Test Loss = 7461.957, Test Accuracy = 0.786, Implict KL value = 197.601
# Step 1700, Training Loss = 9229.549, Test Loss = 8005.156, Test Accuracy = 0.786, Implict KL value = 380.885
# Step 300, Training Loss = 6872.180, Test Loss = 4330.636, Test Accuracy = 0.882, Implict KL value = 607.091
# Step 400, Training Loss = 5320.989, Test Loss = 4242.969, Test Accuracy = 0.882, Implict KL value = 633.659
# Step 500, Training Loss = 4494.255, Test Loss = 3595.478, Test Accuracy = 0.898, Implict KL value = 495.580
# Step 600, Training Loss = 8327.741, Test Loss = 6062.458, Test Accuracy = 0.832, Implict KL value = 469.227
# Step 700, Training Loss = 5088.783, Test Loss = 3295.168, Test Accuracy = 0.908, Implict KL value = 456.731
# Step 800, Training Loss = 3254.904, Test Loss = 4340.381, Test Accuracy = 0.882, Implict KL value = -121.960
# Step 900, Training Loss = 3915.255, Test Loss = 3882.062, Test Accuracy = 0.890, Implict KL value = -551.152
# Step 1000, Training Loss = 6551.970, Test Loss = 3793.472, Test Accuracy = 0.897, Implict KL value = 254.266
# Step 1100, Training Loss = 5088.300, Test Loss = 4217.356, Test Accuracy = 0.885, Implict KL value = 227.628
# Step 1200, Training Loss = 5485.992, Test Loss = 3327.854, Test Accuracy = 0.907, Implict KL value = 405.089
# Step 1300, Training Loss = 4945.193, Test Loss = 3287.532, Test Accuracy = 0.906, Implict KL value = 424.573
# Step 1400, Training Loss = 5917.397, Test Loss = 4138.159, Test Accuracy = 0.891, Implict KL value = 436.239
# Step 1500, Training Loss = 7134.079, Test Loss = 3119.777, Test Accuracy = 0.909, Implict KL value = 452.592
# Step 1600, Training Loss = 6079.315, Test Loss = 4050.206, Test Accuracy = 0.891, Implict KL value = 479.310
# Step 1700, Training Loss = 6474.437, Test Loss = 4619.834, Test Accuracy = 0.871, Implict KL value = 506.826
# Step 1800, Training Loss = 4771.233, Test Loss = 3348.484, Test Accuracy = 0.909, Implict KL value = 517.132
# Step 1900, Training Loss = 5580.626, Test Loss = 3266.681, Test Accuracy = 0.906, Implict KL value = 495.093
# Step 2000, Training Loss = 3749.883, Test Loss = 3516.447, Test Accuracy = 0.903, Implict KL value = 475.222
# Step 2100, Training Loss = 4748.750, Test Loss = 4031.665, Test Accuracy = 0.895, Implict KL value = 525.493
# Step 2200, Training Loss = 4263.044, Test Loss = 4034.359, Test Accuracy = 0.892, Implict KL value = 408.418
# Step 2300, Training Loss = 5286.661, Test Loss = 3405.212, Test Accuracy = 0.906, Implict KL value = 481.452
# Step 2400, Training Loss = 5309.238, Test Loss = 3776.559, Test Accuracy = 0.896, Implict KL value = 651.989
# Step 2500, Training Loss = 6059.628, Test Loss = 4089.420, Test Accuracy = 0.893, Implict KL value = 443.890
# Step 2600, Training Loss = 6105.618, Test Loss = 3392.962, Test Accuracy = 0.907, Implict KL value = 507.893
# Step 2700, Training Loss = 5944.464, Test Loss = 3582.702, Test Accuracy = 0.902, Implict KL value = 481.115
# Step 2800, Training Loss = 6347.986, Test Loss = 3549.061, Test Accuracy = 0.899, Implict KL value = 519.158
# Step 2900, Training Loss = 5783.939, Test Loss = 3544.618, Test Accuracy = 0.904, Implict KL value = 446.499
# Step 3000, Training Loss = 5405.887, Test Loss = 3999.838, Test Accuracy = 0.892, Implict KL value = 397.151
# Step 3100, Training Loss = 3950.576, Test Loss = 4117.727, Test Accuracy = 0.890, Implict KL value = 552.107
# Step 3200, Training Loss = 5515.264, Test Loss = 3298.418, Test Accuracy = 0.904, Implict KL value = 531.287
# Step 3300, Training Loss = 4719.968, Test Loss = 3404.217, Test Accuracy = 0.906, Implict KL value = 441.047
# Step 3400, Training Loss = 4746.070, Test Loss = 3534.032, Test Accuracy = 0.899, Implict KL value = 417.927
# Step 3500, Training Loss = 5234.549, Test Loss = 4041.245, Test Accuracy = 0.893, Implict KL value = 532.709
# Step 3600, Training Loss = 5200.041, Test Loss = 3840.705, Test Accuracy = 0.897, Implict KL value = 314.511
# Step 3700, Training Loss = 6190.855, Test Loss = 3552.400, Test Accuracy = 0.902, Implict KL value = 403.593
# Step 3800, Training Loss = 5014.795, Test Loss = 4134.560, Test Accuracy = 0.888, Implict KL value = 321.377
# Step 3900, Training Loss = 4770.691, Test Loss = 4183.606, Test Accuracy = 0.886, Implict KL value = 329.109
# Step 4000, Training Loss = 4626.500, Test Loss = 4349.326, Test Accuracy = 0.875, Implict KL value = -373.830
# Step 4100, Training Loss = 2133.564, Test Loss = 4205.874, Test Accuracy = 0.884, Implict KL value = -2280.283
# Step 4200, Training Loss = 5154.968, Test Loss = 4001.134, Test Accuracy = 0.895, Implict KL value = 461.582
# Step 4300, Training Loss = 5124.452, Test Loss = 3507.218, Test Accuracy = 0.906, Implict KL value = 21.038
# Step 4400, Training Loss = 5854.662, Test Loss = 3694.650, Test Accuracy = 0.900, Implict KL value = 332.107
# Step 4500, Training Loss = 5560.351, Test Loss = 3117.104, Test Accuracy = 0.917, Implict KL value = 430.101
# Step 4600, Training Loss = 4996.426, Test Loss = 3167.822, Test Accuracy = 0.915, Implict KL value = 405.876
# Step 4700, Training Loss = 6246.988, Test Loss = 3073.966, Test Accuracy = 0.914, Implict KL value = 421.854
# ...
# Step 700, Training Loss = 1401.869, Test Loss = 1047.024, Test Accuracy = 0.972, Implict KL value = 117.638
# Step 800, Training Loss = 1947.567, Test Loss = 879.297, Test Accuracy = 0.976, Implict KL value = 148.984
# Step 900, Training Loss = 918.831, Test Loss = 822.461, Test Accuracy = 0.979, Implict KL value = 153.206
# Step 1000, Training Loss = 1568.320, Test Loss = 983.647, Test Accuracy = 0.972, Implict KL value = 160.570
# Step 1100, Training Loss = 1556.392, Test Loss = 717.110, Test Accuracy = 0.981, Implict KL value = 146.290
# Step 1200, Training Loss = 1162.504, Test Loss = 890.413, Test Accuracy = 0.977, Implict KL value = 145.317
# Step 1300, Training Loss = 1106.888, Test Loss = 517.518, Test Accuracy = 0.988, Implict KL value = 129.750
# Step 1400, Training Loss = 1210.905, Test Loss = 894.253, Test Accuracy = 0.976, Implict KL value = 151.350
# Step 1500, Training Loss = 2295.300, Test Loss = 835.353, Test Accuracy = 0.979, Implict KL value = 168.527
# Step 1600, Training Loss = 1619.559, Test Loss = 776.160, Test Accuracy = 0.980, Implict KL value = 153.703
# Step 1700, Training Loss = 1386.401, Test Loss = 844.045, Test Accuracy = 0.977, Implict KL value = 146.682
# Step 1800, Training Loss = 1283.534, Test Loss = 903.093, Test Accuracy = 0.975, Implict KL value = 108.138
# Step 1900, Training Loss = 1152.532, Test Loss = 766.923, Test Accuracy = 0.979, Implict KL value = 112.024
# Step 2000, Training Loss = 1008.076, Test Loss = 768.586, Test Accuracy = 0.977, Implict KL value = 124.219
# Step 2100, Training Loss = 1919.486, Test Loss = 735.823, Test Accuracy = 0.980, Implict KL value = 156.756
# Step 2200, Training Loss = 2058.720, Test Loss = 554.196, Test Accuracy = 0.986, Implict KL value = 189.951
# Step 2300, Training Loss = 3336.262, Test Loss = 2233.977, Test Accuracy = 0.943, Implict KL value = 162.922
# Step 2400, Training Loss = 1331.783, Test Loss = 834.161, Test Accuracy = 0.977, Implict KL value = 186.120
# Step 2500, Training Loss = 1028.845, Test Loss = 1043.013, Test Accuracy = 0.972, Implict KL value = 157.283
# Step 2600, Training Loss = 1579.542, Test Loss = 904.157, Test Accuracy = 0.978, Implict KL value = 19.184
# Step 2700, Training Loss = 1476.088, Test Loss = 579.279, Test Accuracy = 0.984, Implict KL value = 66.491
# Step 2800, Training Loss = 1071.427, Test Loss = 838.889, Test Accuracy = 0.979, Implict KL value = 138.925
# Step 2900, Training Loss = 1655.297, Test Loss = 841.605, Test Accuracy = 0.978, Implict KL value = 149.446
# Step 3000, Training Loss = 804.686, Test Loss = 883.871, Test Accuracy = 0.974, Implict KL value = 167.274
# Step 3100, Training Loss = 844.979, Test Loss = 887.842, Test Accuracy = 0.976, Implict KL value = 109.148
# Step 3200, Training Loss = 1581.677, Test Loss = 862.487, Test Accuracy = 0.977, Implict KL value = 124.370
# Step 3300, Training Loss = 1495.296, Test Loss = 807.854, Test Accuracy = 0.978, Implict KL value = 110.485
# Step 3400, Training Loss = 986.736, Test Loss = 740.807, Test Accuracy = 0.979, Implict KL value = 154.356
# Step 3500, Training Loss = 1679.683, Test Loss = 729.343, Test Accuracy = 0.979, Implict KL value = 148.386
# Step 3600, Training Loss = 2537.528, Test Loss = 1332.935, Test Accuracy = 0.965, Implict KL value = 150.577
# Step 3700, Training Loss = 1651.897, Test Loss = 1056.191, Test Accuracy = 0.969, Implict KL value = 186.545
# Step 3800, Training Loss = 1280.958, Test Loss = 1100.714, Test Accuracy = 0.971, Implict KL value = 203.361
# Step 3900, Training Loss = 1318.870, Test Loss = 632.852, Test Accuracy = 0.982, Implict KL value = 123.564
# Step 4000, Training Loss = 1652.281, Test Loss = 868.235, Test Accuracy = 0.978, Implict KL value = 149.517
# Step 4100, Training Loss = 1431.467, Test Loss = 641.011, Test Accuracy = 0.983, Implict KL value = 141.219
# Step 4200, Training Loss = 1353.267, Test Loss = 732.163, Test Accuracy = 0.979, Implict KL value = 122.526
# Step 4300, Training Loss = 1506.421, Test Loss = 815.763, Test Accuracy = 0.976, Implict KL value = 180.598
# Step 4400, Training Loss = 1840.715, Test Loss = 1238.206, Test Accuracy = 0.964, Implict KL value = 155.231
# Step 4500, Training Loss = 1355.227, Test Loss = 788.773, Test Accuracy = 0.977, Implict KL value = 158.279
# Step 4600, Training Loss = 1490.423, Test Loss = 839.099, Test Accuracy = 0.977, Implict KL value = 88.788
# Step 4700, Training Loss = 1959.502, Test Loss = 1100.678, Test Accuracy = 0.971, Implict KL value = 94.153
# Step 4800, Training Loss = 1403.050, Test Loss = 882.501, Test Accuracy = 0.975, Implict KL value = 152.776
# Step 4900, Training Loss = 765.138, Test Loss = 1021.195, Test Accuracy = 0.974, Implict KL value = 157.256
# Step 5000, Training Loss = 1860.341, Test Loss = 881.256, Test Accuracy = 0.977, Implict KL value = 119.424
# Step 5100, Training Loss = 808.686, Test Loss = 832.341, Test Accuracy = 0.978, Implict KL value = 158.709
# Step 5200, Training Loss = 1162.313, Test Loss = 749.699, Test Accuracy = 0.977, Implict KL value = 169.408
# Step 5300, Training Loss = 1107.883, Test Loss = 1034.535, Test Accuracy = 0.972, Implict KL value = 196.582
# Step 5400, Training Loss = 1869.303, Test Loss = 723.012, Test Accuracy = 0.979, Implict KL value = 189.939
# Step 5500, Training Loss = 1985.431, Test Loss = 904.379, Test Accuracy = 0.977, Implict KL value = 165.564
# Step 5600, Training Loss = 1643.030, Test Loss = 1158.211, Test Accuracy = 0.970, Implict KL value = 181.218
# Step 5700, Training Loss = 1550.898, Test Loss = 781.412, Test Accuracy = 0.977, Implict KL value = 195.655
# Step 5800, Training Loss = 1185.565, Test Loss = 943.995, Test Accuracy = 0.974, Implict KL value = 224.298
# Step 5900, Training Loss = 1759.312, Test Loss = 979.953, Test Accuracy = 0.974, Implict KL value = 177.234
# Step 6000, Training Loss = 1697.877, Test Loss = 820.070, Test Accuracy = 0.977, Implict KL value = 147.072
# Step 6100, Training Loss = 1187.752, Test Loss = 960.190, Test Accuracy = 0.974, Implict KL value = 182.009
# Step 6200, Training Loss = 1356.551, Test Loss = 618.479, Test Accuracy = 0.982, Implict KL value = 166.056
# Step 6300, Training Loss = 1249.357, Test Loss = 850.344, Test Accuracy = 0.976, Implict KL value = 169.361
# Step 0, Training Loss = 1793.210, Test Loss = 945.066, Test Accuracy = 0.975, Implict KL value = 148.707
# Step 1, Training Loss = 1623.705, Test Loss = 886.679, Test Accuracy = 0.978, Implict KL value = 121.630
# Step 100, Training Loss = 1183.462, Test Loss = 1137.599, Test Accuracy = 0.970, Implict KL value = 108.860
# Step 200, Training Loss = 804.827, Test Loss = 788.380, Test Accuracy = 0.979, Implict KL value = 161.237
# Step 300, Training Loss = 1846.860, Test Loss = 766.001, Test Accuracy = 0.980, Implict KL value = 156.686
# Step 400, Training Loss = 1737.679, Test Loss = 675.874, Test Accuracy = 0.983, Implict KL value = 196.541
# Step 500, Training Loss = 1680.767, Test Loss = 1213.283, Test Accuracy = 0.966, Implict KL value = 156.223
# Step 600, Training Loss = 975.892, Test Loss = 969.516, Test Accuracy = 0.974, Implict KL value = 136.973
# Step 700, Training Loss = 1271.788, Test Loss = 1128.571, Test Accuracy = 0.969, Implict KL value = 59.133
# Step 800, Training Loss = 1869.118, Test Loss = 637.486, Test Accuracy = 0.985, Implict KL value = 99.578
# Step 900, Training Loss = 523.113, Test Loss = 762.768, Test Accuracy = 0.980, Implict KL value = 100.428
# Step 1000, Training Loss = 1752.647, Test Loss = 609.756, Test Accuracy = 0.985, Implict KL value = 130.538
# Step 1100, Training Loss = 1670.405, Test Loss = 1073.594, Test Accuracy = 0.973, Implict KL value = 172.336
# Step 1200, Training Loss = 1218.464, Test Loss = 908.556, Test Accuracy = 0.976, Implict KL value = 134.876
# Step 1300, Training Loss = 694.169, Test Loss = 852.537, Test Accuracy = 0.978, Implict KL value = 143.845
# Step 1400, Training Loss = 1625.117, Test Loss = 715.115, Test Accuracy = 0.980, Implict KL value = 143.405
# Step 1500, Training Loss = 1017.417, Test Loss = 602.094, Test Accuracy = 0.984, Implict KL value = 133.753
# Step 1600, Training Loss = 1249.917, Test Loss = 958.180, Test Accuracy = 0.972, Implict KL value = 110.804
# Step 1700, Training Loss = 1037.786, Test Loss = 1132.643, Test Accuracy = 0.971, Implict KL value = 135.447
# Step 1800, Training Loss = 854.145, Test Loss = 688.037, Test Accuracy = 0.980, Implict KL value = 125.097
# Step 1900, Training Loss = 1768.645, Test Loss = 927.227, Test Accuracy = 0.976, Implict KL value = -7.029
# Step 2000, Training Loss = 1290.903, Test Loss = 924.777, Test Accuracy = 0.975, Implict KL value = 121.040
# Step 2100, Training Loss = 2013.014, Test Loss = 787.314, Test Accuracy = 0.979, Implict KL value = 36.727
# Step 2200, Training Loss = 1050.491, Test Loss = 867.185, Test Accuracy = 0.977, Implict KL value = 144.594
# Step 2300, Training Loss = 1761.587, Test Loss = 867.279, Test Accuracy = 0.977, Implict KL value = 60.731
# Step 2400, Training Loss = 1743.256, Test Loss = 786.521, Test Accuracy = 0.978, Implict KL value = 166.789
# Step 2500, Training Loss = 1776.217, Test Loss = 979.833, Test Accuracy = 0.975, Implict KL value = 156.730
# Step 2600, Training Loss = 1827.320, Test Loss = 814.249, Test Accuracy = 0.978, Implict KL value = 169.233
# Step 2700, Training Loss = 1596.141, Test Loss = 707.044, Test Accuracy = 0.979, Implict KL value = 122.950
# Step 2800, Training Loss = 964.519, Test Loss = 1895.169, Test Accuracy = 0.952, Implict KL value = 149.225
# Step 2900, Training Loss = 1270.653, Test Loss = 650.131, Test Accuracy = 0.982, Implict KL value = 204.923
# Step 3000, Training Loss = 1602.032, Test Loss = 773.978, Test Accuracy = 0.978, Implict KL value = 158.565
# Step 3100, Training Loss = 1656.832, Test Loss = 842.264, Test Accuracy = 0.977, Implict KL value = 162.808
# Step 3200, Training Loss = 2318.600, Test Loss = 764.660, Test Accuracy = 0.980, Implict KL value = 194.029
# Step 3300, Training Loss = 1625.195, Test Loss = 787.553, Test Accuracy = 0.979, Implict KL value = 193.432
# Step 3400, Training Loss = 1291.062, Test Loss = 710.836, Test Accuracy = 0.981, Implict KL value = 133.303
# Step 3500, Training Loss = 1352.689, Test Loss = 886.185, Test Accuracy = 0.976, Implict KL value = 89.088
# Step 3600, Training Loss = 1663.429, Test Loss = 839.390, Test Accuracy = 0.978, Implict KL value = 21.093
# Step 3700, Training Loss = 1353.002, Test Loss = 872.318, Test Accuracy = 0.976, Implict KL value = 195.873
# Step 3800, Training Loss = 1715.256, Test Loss = 817.138, Test Accuracy = 0.977, Implict KL value = 190.799
# Step 3900, Training Loss = 1899.791, Test Loss = 577.814, Test Accuracy = 0.983, Implict KL value = 198.539
# Step 4000, Training Loss = 1389.418, Test Loss = 908.869, Test Accuracy = 0.975, Implict KL value = 149.847
# Step 4100, Training Loss = 1290.108, Test Loss = 886.971, Test Accuracy = 0.975, Implict KL value = 256.562
# Step 4200, Training Loss = 1095.395, Test Loss = 672.949, Test Accuracy = 0.980, Implict KL value = 135.219
# Step 4300, Training Loss = 910.524, Test Loss = 816.821, Test Accuracy = 0.979, Implict KL value = 111.309
# Step 4400, Training Loss = 1803.998, Test Loss = 1011.218, Test Accuracy = 0.974, Implict KL value = 60.981
# Step 4500, Training Loss = 1383.575, Test Loss = 892.519, Test Accuracy = 0.977, Implict KL value = 159.183
# Step 4600, Training Loss = 2883.807, Test Loss = 1443.209, Test Accuracy = 0.958, Implict KL value = 170.593
# Step 4700, Training Loss = 839.153, Test Loss = 850.832, Test Accuracy = 0.979, Implict KL value = 210.881
# Step 4800, Training Loss = 1484.518, Test Loss = 790.434, Test Accuracy = 0.981, Implict KL value = 184.230
# Step 4900, Training Loss = 1090.435, Test Loss = 803.595, Test Accuracy = 0.978, Implict KL value = 188.593
# Step 5000, Training Loss = 1007.292, Test Loss = 923.591, Test Accuracy = 0.974, Implict KL value = 150.442
# Step 5100, Training Loss = 976.501, Test Loss = 833.910, Test Accuracy = 0.979, Implict KL value = 177.166
# Step 5200, Training Loss = 1334.884, Test Loss = 873.337, Test Accuracy = 0.976, Implict KL value = 248.872
# Step 5300, Training Loss = 1038.185, Test Loss = 806.546, Test Accuracy = 0.978, Implict KL value = 200.581
# Step 5400, Training Loss = 1647.636, Test Loss = 754.186, Test Accuracy = 0.978, Implict KL value = 162.255
# Step 5500, Training Loss = 1653.690, Test Loss = 773.631, Test Accuracy = 0.980, Implict KL value = 154.270
# Step 5600, Training Loss = 1890.984, Test Loss = 825.447, Test Accuracy = 0.979, Implict KL value = 159.483
# Step 5700, Training Loss = 1379.597, Test Loss = 920.159, Test Accuracy = 0.977, Implict KL value = 189.071
# Step 5800, Training Loss = 1760.646, Test Loss = 830.995, Test Accuracy = 0.978, Implict KL value = 171.956
# Step 5900, Training Loss = 1295.942, Test Loss = 1021.952, Test Accuracy = 0.972, Implict KL value = 171.655
# Step 6000, Training Loss = 1364.671, Test Loss = 949.149, Test Accuracy = 0.976, Implict KL value = 205.280
# Step 6100, Training Loss = 1508.289, Test Loss = 1163.627, Test Accuracy = 0.968, Implict KL value = 173.512
# Step 6200, Training Loss = 1304.453, Test Loss = 824.202, Test Accuracy = 0.979, Implict KL value = 166.151
# Step 6300, Training Loss = 1319.776, Test Loss = 809.489, Test Accuracy = 0.978, Implict KL value = 116.873
# Step 0, Training Loss = 1580.552, Test Loss = 612.998, Test Accuracy = 0.983, Implict KL value = 115.407
# Step 1, Training Loss = 1361.234, Test Loss = 551.332, Test Accuracy = 0.985, Implict KL value = 171.301
# Step 100, Training Loss = 1453.205, Test Loss = 666.009, Test Accuracy = 0.983, Implict KL value = 168.472
# Step 200, Training Loss = 1700.069, Test Loss = 614.650, Test Accuracy = 0.984, Implict KL value = 139.123
# Step 300, Training Loss = 697.970, Test Loss = 1246.445, Test Accuracy = 0.965, Implict KL value = 145.563
# Step 400, Training Loss = 3613.166, Test Loss = 1742.500, Test Accuracy = 0.950, Implict KL value = 170.988
# Step 500, Training Loss = 2055.911, Test Loss = 791.022, Test Accuracy = 0.978, Implict KL value = 229.422
# Step 600, Training Loss = 1490.112, Test Loss = 921.122, Test Accuracy = 0.976, Implict KL value = 255.252
# Step 700, Training Loss = 1690.030, Test Loss = 741.932, Test Accuracy = 0.982, Implict KL value = 252.840
# Step 800, Training Loss = 1142.231, Test Loss = 667.627, Test Accuracy = 0.981, Implict KL value = 208.011
# Step 900, Training Loss = 1512.252, Test Loss = 726.208, Test Accuracy = 0.982, Implict KL value = 233.651
# Step 1000, Training Loss = 1050.906, Test Loss = 533.362, Test Accuracy = 0.986, Implict KL value = 241.140
# Step 1100, Training Loss = 1252.491, Test Loss = 1013.953, Test Accuracy = 0.973, Implict KL value = 121.558
# Step 1200, Training Loss = 1071.055, Test Loss = 771.366, Test Accuracy = 0.979, Implict KL value = 125.423
# Step 1300, Training Loss = 1535.665, Test Loss = 787.574, Test Accuracy = 0.978, Implict KL value = 108.724
# Step 1400, Training Loss = 1724.392, Test Loss = 814.168, Test Accuracy = 0.980, Implict KL value = 134.348
# Step 1500, Training Loss = 1569.203, Test Loss = 752.067, Test Accuracy = 0.981, Implict KL value = 82.130
# Step 1600, Training Loss = 1950.354, Test Loss = 683.814, Test Accuracy = 0.981, Implict KL value = 111.629
# Step 1700, Training Loss = 979.693, Test Loss = 1037.223, Test Accuracy = 0.969, Implict KL value = 99.798
# Step 1800, Training Loss = 1057.873, Test Loss = 938.265, Test Accuracy = 0.975, Implict KL value = 103.747
# Step 1900, Training Loss = 1316.662, Test Loss = 870.320, Test Accuracy = 0.977, Implict KL value = 189.318
# Step 2000, Training Loss = 1833.596, Test Loss = 807.026, Test Accuracy = 0.977, Implict KL value = 144.940
# Step 2100, Training Loss = 978.526, Test Loss = 603.502, Test Accuracy = 0.984, Implict KL value = 73.621
# Step 2200, Training Loss = 1587.179, Test Loss = 722.106, Test Accuracy = 0.980, Implict KL value = 182.149
# Step 2300, Training Loss = 1269.106, Test Loss = 643.907, Test Accuracy = 0.984, Implict KL value = 219.555
# Step 2400, Training Loss = 1472.096, Test Loss = 902.405, Test Accuracy = 0.975, Implict KL value = 171.918

# %%
smile_ivae.summary()
